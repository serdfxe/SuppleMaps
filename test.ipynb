# %%
from app.database import *

from app.models.map import *

# %%
for p in Poi.all():
    print(p.name)
    imgs = ""
    while True:
        s = input()
        if s != "":
            imgs += s+" "
        else:
            break
    Poi.update(p, image=imgs)
    print("Success!")
# Out:
# Центр креативного арт-дизайна La Atmosfera
# Success!
# Павильон №1. Экспозиция Третьяковской галереи (Центральный)
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File c:\Users\pavel\Desktop\Supple Maps\pr\venv\lib\site-packages\sqlalchemy\engine\base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File c:\Users\pavel\Desktop\Supple Maps\pr\venv\lib\site-packages\sqlalchemy\engine\default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# ...
